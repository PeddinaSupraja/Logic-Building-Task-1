# %% [markdown]
# <a href="https://colab.research.google.com/github/PeddinaSupraja/Logic-Building-Task-1/blob/main/Day3_Problem_Solving.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Problem 1:- Employee Performance Bonus Eligibility**

# %%
employees = {
      "Ravi": 92,
      "Anita": 88,
      "Kiran": 92,
      "Suresh": 85
}
max_score = 0
highest_performers = []
for emp, score in employees.items():
  if score > max_score:
    max_score = score
    highest_performers = [emp]
  elif score == max_score:
    highest_performers.append(emp)
print(f"Top Performers Eligible for Bonus: {', '.join(highest_performers)} (Score: {max_score})")
# Out:
# Top Performers Eligible for Bonus: Ravi, Kiran (Score: 92)

# %% [markdown]
# # **Problem 2:- Search Query Keyword Analysis**

# %%
print("Search Query Keyword Analysis")
search_query = "Buy mobile phone buy phone online"
# Convert to lowercase and split into words
words = search_query.lower().split()
# Count word frequencies
word_freq = {}
for word in words:
    # Remove punctuation if needed (simple version)
    clean_word = ''.join(char for char in word if char.isalnum())
    word_freq[clean_word] = word_freq.get(clean_word, 0) + 1
# Filter words with frequency > 1
repeated_keywords = {word: count for word, count in word_freq.items() if count > 1}
print(repeated_keywords, "\n")
# Out:
# Search Query Keyword Analysis
# {'buy': 2, 'phone': 2}

# %% [markdown]
# # **Problem 3:- Sensor Data Validation**

# %%
print("Sensor Data Validation")
sensor_readings = [3, 4, 7, 8, 10, 12, 5]
valid_readings = [(index, value) for index, value in enumerate(sensor_readings) if value % 2 == 0]
print("Valid Sensor Readings (Hour, Value):")
print(valid_readings, "\n")
# Out:
# Sensor Data Validation
# Valid Sensor Readings (Hour, Value):
# [(1, 4), (3, 8), (4, 10), (5, 12)]

# %% [markdown]
# # **Problem 4:- Email Domain Usage Analysis**

# %%
print(" Email Domain Usage Analysis")
emails = [
    "ravi@gmail.com",
    "anita@yahoo.com",
    "kiran@gmail.com",
    "suresh@gmail.com",
    "meena@yahoo.com"
]
# Count domain usage
domain_count = {}
for email in emails:
    domain = email.split('@')[1]
    domain_count[domain] = domain_count.get(domain, 0) + 1
# Calculate percentage
total_emails = len(emails)
for domain, count in domain_count.items():
    percentage = (count / total_emails) * 100
    print(f"{domain}: {int(percentage)}%")
print()
# Out:
#  Email Domain Usage Analysis
# gmail.com: 60%
# yahoo.com: 40%

# %% [markdown]
# # **Problem 5:- Sales Spike Detection**

# %%
print("Sales Spike Detection")
sales = [1200, 1500, 900, 2200, 1400, 3000]
# Calculate average sales
avg_sales = sum(sales) / len(sales)
# Detect spikes (>30% above average)
for day, sale in enumerate(sales, start=1):
    if sale > 1.3 * avg_sales:
        print(f"Day {day}: {sale}")
print()
# Out:
# Sales Spike Detection
# Day 6: 3000

# %% [markdown]
# # **Problem 6:- Duplicate User ID Detection**

# %%
print("Duplicate User ID Detection")
user_ids = ["user1", "user2", "user1", "user3", "user1", "user3"]
# Count occurrences
id_count = {}
for uid in user_ids:
    id_count[uid] = id_count.get(uid, 0) + 1
# Filter duplicates and display
for uid, count in id_count.items():
    if count > 1:
        print(f"{uid} → {count} times")
# Out:
# Duplicate User ID Detection
# user1 → 3 times
# user3 → 2 times
